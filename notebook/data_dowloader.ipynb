# %%
# !wget https://dataverse.harvard.edu/api/access/datafile/6345597  /teamspace/uploads
# Out:
# --2024-08-27 10:52:23--  https://dataverse.harvard.edu/api/access/datafile/6345597
# Resolving dataverse.harvard.edu (dataverse.harvard.edu)... 34.227.38.125, 18.235.100.148, 54.88.180.8
# Connecting to dataverse.harvard.edu (dataverse.harvard.edu)|34.227.38.125|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/J0PQIW/18184b21d00-778dd4e8c7ad?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27%2520EEG%2520data%2520evoked%2520by%2520Different%2520Odor%2520Types%2520established%2520by%2520Tianjin%2520University%2520%2528EegDot%2529.zip&response-content-type=application%2Fzip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240827T105223Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20240827%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=ec549121187e3d2e6fbc1957f44230b65ce69149e526189ed1a9ebda79ee2b30 [following]
# ...

# %%
# !unzip 6345597
# Out:
# Archive:  6345597
#    creating: Olfactory EEG data set induced by different odor types/
#   inflating: Olfactory EEG data set induced by different odor types/Explanation of olfactory EEG data set induced by different odor types.docx
#    creating: Olfactory EEG data set induced by different odor types/Sub. 1/
#    creating: Olfactory EEG data set induced by different odor types/Sub. 1/A/
#   inflating: Olfactory EEG data set induced by different odor types/Sub. 1/A/datafile001.ns2
#   inflating: Olfactory EEG data set induced by different odor types/Sub. 1/A/datafile002.ns2
#   inflating: Olfactory EEG data set induced by different odor types/Sub. 1/A/datafile003.ns2
#   inflating: Olfactory EEG data set induced by different odor types/Sub. 1/A/datafile004.ns2
#   inflating: Olfactory EEG data set induced by different odor types/Sub. 1/A/datafile005.ns2
#   inflating: Olfactory EEG data set induced by different odor types/Sub. 1/A/datafile006.ns2
# ...
